# %% [markdown]
# ## Pandas Cheat Sheet
#
# Useful Pandas functionality and methods

# %%
import numpy as np
import pandas as pd

# %%
# read data from csv files and concat them
df1 = pd.read_csv('../data/wine-reviews/winemag-data_first150k.csv')
df2 = pd.read_csv('../data/wine-reviews/winemag-data-130k-v2.csv')
df = pd.concat([df1, df2])
len(df)
# Out:
# 280901

# %%
# drop duplicates
df = df.drop_duplicates()
df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2 taster_name taster_twitter_handle  \
# 0        Napa Valley               Napa         NaN                   NaN
# 1               Toro                NaN         NaN                   NaN
# 2     Knights Valley             Sonoma         NaN                   NaN
# 3  Willamette Valley  Willamette Valley         NaN                   NaN
# 4             Bandol                NaN         NaN                   NaN
#
#   title             variety                   winery
# 0   NaN  Cabernet Sauvignon                    Heitz
# 1   NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2   NaN     Sauvignon Blanc                 Macauley
# 3   NaN          Pinot Noir                    Ponzi
# 4   NaN  Provence red blend     Domaine de la Bégude

# %%
# inspect the first ten items
df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2 taster_name taster_twitter_handle  \
# 0        Napa Valley               Napa         NaN                   NaN
# 1               Toro                NaN         NaN                   NaN
# 2     Knights Valley             Sonoma         NaN                   NaN
# 3  Willamette Valley  Willamette Valley         NaN                   NaN
# 4             Bandol                NaN         NaN                   NaN
#
#   title             variety                   winery
# 0   NaN  Cabernet Sauvignon                    Heitz
# 1   NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2   NaN     Sauvignon Blanc                 Macauley
# 3   NaN          Pinot Noir                    Ponzi
# 4   NaN  Provence red blend     Domaine de la Bégude

# %%
# last ten items
df.tail()
# Out:
#         Unnamed: 0  country  \
# 129966      129966  Germany
# 129967      129967       US
# 129968      129968   France
# 129969      129969   France
# 129970      129970   France
#
#                                               description  \
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# 129966      NaN           NaN  Anna Lee C. Iijima                   NaN
# 129967   Oregon  Oregon Other        Paul Gregutt           @paulgwine
# 129968   Alsace           NaN          Roger Voss            @vossroger
# 129969   Alsace           NaN          Roger Voss            @vossroger
# 129970   Alsace           NaN          Roger Voss            @vossroger
#
#                                                     title         variety  \
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit

# %%
# inspect the columns
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
# slice frame by headers
df2 = df[['country', 'province', 'points']]
df2.head(5)
# Out:
#   country        province  points
# 0      US      California      96
# 1   Spain  Northern Spain      96
# 2      US      California      96
# 3      US          Oregon      96
# 4  France        Provence      95

# %%
# find the max points/score
df2['points'].max()
# Out:
# 100

# %%
# get summary statitics
df2.describe()
# Out:
#               points
# count  280901.000000
# mean       88.146934
# std         3.151528
# min        80.000000
# 25%        86.000000
# 50%        88.000000
# 75%        90.000000
# max       100.000000

# %%
# filter data
predicate = df['points'] > 90
top_wines = df[predicate]
top_wines.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2 taster_name taster_twitter_handle  \
# 0        Napa Valley               Napa         NaN                   NaN
# 1               Toro                NaN         NaN                   NaN
# 2     Knights Valley             Sonoma         NaN                   NaN
# 3  Willamette Valley  Willamette Valley         NaN                   NaN
# 4             Bandol                NaN         NaN                   NaN
#
#   title             variety                   winery
# 0   NaN  Cabernet Sauvignon                    Heitz
# 1   NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2   NaN     Sauvignon Blanc                 Macauley
# 3   NaN          Pinot Noir                    Ponzi
# 4   NaN  Provence red blend     Domaine de la Bégude

# %%
# create a new column on the fly
top_wines['full_region'] = top_wines['region_1'].map(lambda x: str(x) + ', ') + top_wines['region_2']
top_wines.head()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2 taster_name taster_twitter_handle  \
# 0        Napa Valley               Napa         NaN                   NaN
# 1               Toro                NaN         NaN                   NaN
# 2     Knights Valley             Sonoma         NaN                   NaN
# 3  Willamette Valley  Willamette Valley         NaN                   NaN
# 4             Bandol                NaN         NaN                   NaN
#
#   title             variety                   winery  \
# 0   NaN  Cabernet Sauvignon                    Heitz
# 1   NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2   NaN     Sauvignon Blanc                 Macauley
# 3   NaN          Pinot Noir                    Ponzi
# 4   NaN  Provence red blend     Domaine de la Bégude
#
#                             full_region
# 0                     Napa Valley, Napa
# 1                                   NaN
# 2                Knights Valley, Sonoma
# 3  Willamette Valley, Willamette Valley
# 4                                   NaN

# %%
# drop column
top_wines.drop('full_region', axis=1, inplace=True)
top_wines.head()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2 taster_name taster_twitter_handle  \
# 0        Napa Valley               Napa         NaN                   NaN
# 1               Toro                NaN         NaN                   NaN
# 2     Knights Valley             Sonoma         NaN                   NaN
# 3  Willamette Valley  Willamette Valley         NaN                   NaN
# 4             Bandol                NaN         NaN                   NaN
#
#   title             variety                   winery
# 0   NaN  Cabernet Sauvignon                    Heitz
# 1   NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2   NaN     Sauvignon Blanc                 Macauley
# 3   NaN          Pinot Noir                    Ponzi
# 4   NaN  Provence red blend     Domaine de la Bégude

# %%
# drop row
dropped = top_wines.drop(0)
dropped.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
# 5           5   Spain  Deep, dense and pure from the opening bell, th...
#
#                             designation  points  price        province  \
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
# 5                             Numanthia      95   73.0  Northern Spain
#
#             region_1           region_2 taster_name taster_twitter_handle  \
# 1               Toro                NaN         NaN                   NaN
# 2     Knights Valley             Sonoma         NaN                   NaN
# 3  Willamette Valley  Willamette Valley         NaN                   NaN
# 4             Bandol                NaN         NaN                   NaN
# 5               Toro                NaN         NaN                   NaN
#
#   title             variety                   winery
# 1   NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2   NaN     Sauvignon Blanc                 Macauley
# 3   NaN          Pinot Noir                    Ponzi
# 4   NaN  Provence red blend     Domaine de la Bégude
# 5   NaN       Tinta de Toro                Numanthia

# %%
# indexing
df.loc[0]   # grab item by index label
df.iloc[0]  # grab item by index location
# Out:
# Unnamed: 0                                                               0
# country                                                                 US
# description              This tremendous 100% varietal wine hails from ...
# designation                                              Martha's Vineyard
# points                                                                  96
# price                                                                  235
# province                                                        California
# region_1                                                       Napa Valley
# region_2                                                              Napa
# taster_name                                                            NaN
# taster_twitter_handle                                                  NaN
# title                                                                  NaN
# variety                                                 Cabernet Sauvignon
# winery                                                               Heitz
# Name: 0, dtype: object

# %%
# slice by row and column header
df.loc[1, 'region_1']
# Out:
# 1    Toro
# 1     NaN
# Name: region_1, dtype: object

# %%
# slice subset of frame
df.loc[[1, 2, 3], ['region_1', 'region_2']]
# Out:
#               region_1           region_2
# 1                 Toro                NaN
# 1                  NaN                NaN
# 2       Knights Valley             Sonoma
# 2    Willamette Valley  Willamette Valley
# 3    Willamette Valley  Willamette Valley
# 3  Lake Michigan Shore                NaN

# %%
# and operator
ny_wines = df[(df['country'] == 'US') & (df['province'] == 'New York')]
ny_wines.head()
# Out:
#      Unnamed: 0 country                                        description  \
# 57           57      US  While exuberantly fruity, almost tropical on t...
# 113         113      US  Savory apples and pears mingle into lemon and ...
# 198         198      US  Zesty and mineral, this unoaked, citrusy Chard...
# 199         199      US  Smoke and violet perfume are seductive on this...
# 200         200      US  Intense notes of crushed stone and slate perme...
#
#                 designation  points  price  province             region_1  \
# 57                  Reserve      90   25.0  New York         Finger Lakes
# 113    Castle Hill Vineyard      86   25.0  New York  Hudson River Region
# 198  Ingle Vineyard Unoaked      87   18.0  New York         Finger Lakes
# 199                Semi-Dry      87   14.0  New York         Finger Lakes
# 200                Semi-Dry      87   14.0  New York         Finger Lakes
#
#            region_2 taster_name taster_twitter_handle title     variety  \
# 57     Finger Lakes         NaN                   NaN   NaN    Riesling
# 113  New York Other         NaN                   NaN   NaN    Riesling
# 198    Finger Lakes         NaN                   NaN   NaN  Chardonnay
# 199    Finger Lakes         NaN                   NaN   NaN    Riesling
# 200    Finger Lakes         NaN                   NaN   NaN    Riesling
#
#                    winery
# 57   Dr. Konstantin Frank
# 113             Millbrook
# 198            Heron Hill
# 199            Heron Hill
# 200               Fox Run

# %%
# or operator
napa_wines = df[(df['region_1'] == 'Napa') | (df['region_2'] == 'Napa Valley')]
napa_wines.head()
# Out:
#       Unnamed: 0 country                                        description  \
# 1926        1926      US  Some ageable Cabs are lovely to drink on relea...
# 2942        2942      US  Big, oaky and concentrated, it's rich in coffe...
# 4433        4433      US  Juslyn's wines are made in a tannic style. The...
# 7438        7438      US  This Cabernet shows its Spring Mountain terroi...
# 8711        8711      US  There's something rustic about this Cab. Partl...
#
#                   designation  points  price    province region_1 region_2  \
# 1926                      NaN      90  125.0  California     Napa      NaN
# 2942                  Reserve      87   45.0  California     Napa      NaN
# 4433            Perry's Blend      88   80.0  California     Napa      NaN
# 7438  Premium Limited Edition      87   25.0  California     Napa      NaN
# 8711                      NaN      86  125.0  California     Napa      NaN
#
#      taster_name taster_twitter_handle title                   variety  \
# 1926         NaN                   NaN   NaN        Cabernet Sauvignon
# 2942         NaN                   NaN   NaN        Cabernet Sauvignon
# 4433         NaN                   NaN   NaN  Bordeaux-style Red Blend
# 7438         NaN                   NaN   NaN        Cabernet Sauvignon
# 8711         NaN                   NaN   NaN        Cabernet Sauvignon
#
#                 winery
# 1926  Juslyn Vineyards
# 2942              Unum
# 4433  Juslyn Vineyards
# 7438            Publix
# 8711  Juslyn Vineyards

# %%
# top California merlots under  $20
napa_wines = df[(df['country'] == 'US') & (df['province'] == 'California') & (df['price'] < 20) & (df['variety'] == 'Cabernet Sauvignon')]
napa_wines.sort('points', ascending=False).head()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   This is separate from the ipykernel package so we can avoid doing imports until
#         Unnamed: 0 country                                        description  \
# 19027        19027      US  This is a big but balanced expression of Caber...
# 121686      121686      US  This is a big but balanced expression of Caber...
# 54278        54278      US  A wonderful red wine, full-bodied, dry and ele...
# 83463        83463      US  A wonderfully good wine, especially at this pr...
# 85838        85838      US  A wonderful red wine, full-bodied, dry and ele...
#
#               designation  points  price    province        region_1  \
# 19027                 NaN      93   18.0  California   Central Coast
# 121686                NaN      93   18.0  California   Central Coast
# 54278                 NaN      92   16.0  California  Mendocino-Lake
# 83463   Vintner's Reserve      92   18.0  California     Sonoma-Napa
# 85838                 NaN      92   16.0  California  Mendocino-Lake
#
#              region_2    taster_name taster_twitter_handle  \
# 19027   Central Coast  Matt Kettmann         @mattkettmann
# 121686  Central Coast  Matt Kettmann         @mattkettmann
# 54278     North Coast            NaN                   NaN
# 83463     Napa-Sonoma            NaN                   NaN
# 85838     North Coast            NaN                   NaN
#
#                                                     title             variety  \
# 19027   Smith & Hook 2015 Cabernet Sauvignon (Central ...  Cabernet Sauvignon
# 121686  Smith & Hook 2015 Cabernet Sauvignon (Central ...  Cabernet Sauvignon
# 54278                                                 NaN  Cabernet Sauvignon
# 83463                                                 NaN  Cabernet Sauvignon
# 85838                                                 NaN  Cabernet Sauvignon
#
#                  winery
# 19027      Smith & Hook
# 121686     Smith & Hook
# 54278          Bonterra
# 83463   Kendall-Jackson
# 85838          Bonterra

# %%
# get datatypes of information stored in columns
df.dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
# convert frame to matrix
M = df2.as_matrix()
M
# Out:
# array([['US', 'California', 96],
#        ['Spain', 'Northern Spain', 96],
#        ['US', 'California', 96],
#        ...,
#        ['France', 'Alsace', 90],
#        ['France', 'Alsace', 90],
#        ['France', 'Alsace', 90]], dtype=object)

# %%
# rename index
df2 = df.rename(columns={'Unnamed: 0': 'Index'})
df2 = df2.set_index('Index')
df2.head()
# Out:
#       country                                        description  \
# Index
# 0          US  This tremendous 100% varietal wine hails from ...
# 1       Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2          US  Mac Watson honors the memory of a wine once ma...
# 3          US  This spent 20 months in 30% new French oak, an...
# 4      France  This is the top wine from La Bégude, named aft...
#
#                                 designation  points  price        province  \
# Index
# 0                         Martha's Vineyard      96  235.0      California
# 1      Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2             Special Selected Late Harvest      96   90.0      California
# 3                                   Reserve      96   65.0          Oregon
# 4                                La Brûlade      95   66.0        Provence
#
#                 region_1           region_2 taster_name taster_twitter_handle  \
# Index
# 0            Napa Valley               Napa         NaN                   NaN
# 1                   Toro                NaN         NaN                   NaN
# 2         Knights Valley             Sonoma         NaN                   NaN
# 3      Willamette Valley  Willamette Valley         NaN                   NaN
# 4                 Bandol                NaN         NaN                   NaN
#
#       title             variety                   winery
# Index
# 0       NaN  Cabernet Sauvignon                    Heitz
# 1       NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2       NaN     Sauvignon Blanc                 Macauley
# 3       NaN          Pinot Noir                    Ponzi
# 4       NaN  Provence red blend     Domaine de la Bégude

# %%
# reset index
df2 = df2.reset_index()
df2.head()
# Out:
#    Index country                                        description  \
# 0      0      US  This tremendous 100% varietal wine hails from ...
# 1      1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      2      US  Mac Watson honors the memory of a wine once ma...
# 3      3      US  This spent 20 months in 30% new French oak, an...
# 4      4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2 taster_name taster_twitter_handle  \
# 0        Napa Valley               Napa         NaN                   NaN
# 1               Toro                NaN         NaN                   NaN
# 2     Knights Valley             Sonoma         NaN                   NaN
# 3  Willamette Valley  Willamette Valley         NaN                   NaN
# 4             Bandol                NaN         NaN                   NaN
#
#   title             variety                   winery
# 0   NaN  Cabernet Sauvignon                    Heitz
# 1   NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2   NaN     Sauvignon Blanc                 Macauley
# 3   NaN          Pinot Noir                    Ponzi
# 4   NaN  Provence red blend     Domaine de la Bégude

# %%
# fill in missing data
df2['region_2'] = df2['region_2'].fillna(value=df2['region_1'])
df2['taster_name'] = df2['taster_name'].fillna(value='NA')
df2['taster_twitter_handle'] = df2['taster_twitter_handle'].fillna(value='NA')
df2.head()
# Out:
#    Index country                                        description  \
# 0      0      US  This tremendous 100% varietal wine hails from ...
# 1      1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      2      US  Mac Watson honors the memory of a wine once ma...
# 3      3      US  This spent 20 months in 30% new French oak, an...
# 4      4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2 taster_name taster_twitter_handle  \
# 0        Napa Valley               Napa          NA                    NA
# 1               Toro               Toro          NA                    NA
# 2     Knights Valley             Sonoma          NA                    NA
# 3  Willamette Valley  Willamette Valley          NA                    NA
# 4             Bandol             Bandol          NA                    NA
#
#   title             variety                   winery
# 0   NaN  Cabernet Sauvignon                    Heitz
# 1   NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2   NaN     Sauvignon Blanc                 Macauley
# 3   NaN          Pinot Noir                    Ponzi
# 4   NaN  Provence red blend     Domaine de la Bégude

# %%
# groupby
df3 = df2[['country', 'points']][df2['points'] > 89]
grouped = df3.groupby('country').mean()
grouped.nlargest(10, columns='points')
# Out:
#               points
# country
# England    92.275362
# France     91.865331
# US         91.667858
# Austria    91.606510
# Italy      91.532584
# Germany    91.497748
# Hungary    91.496063
# Portugal   91.466102
# Spain      91.396184
# Australia  91.368613

# %% [markdown]
# ## Series

# %%
labels = ['a', 'b', 'c']
data_list = [10, 20, 30]
arr = np.array(data_list)
d = {'a': 10, 'b': 20, 'c': 30}

# %%
# create a series
pd.Series(data_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
# add labels to the series index
pd.Series(data=data_list, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# get an item by index
s1 = pd.Series([1, 2, 3, 4], index=['NYC', 'LA', 'DEN', 'CHI'])
s1['NYC']
# Out:
# 1

# %%
# perform operations on two series
s2 = pd.Series([2, 4, 6, 8], index=['NYC', 'MIA', 'BUF', 'DEN'])
s1 + s2
# Out:
# BUF     NaN
# CHI     NaN
# DEN    11.0
# LA      NaN
# MIA     NaN
# NYC     3.0
# dtype: float64

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame
